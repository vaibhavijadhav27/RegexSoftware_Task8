# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavijadhav27/RegexSoftware_Task8/blob/main/RegexSoftware_Task8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**TASK** **8**
# ## **Registration ID: SIRSS2278**
# **Name: Vaibhavi Jadhav**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
train_data = pd.read_csv('heart.csv') 
test_data = pd.read_csv('o2Saturation.csv')

# %%
train_data.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  ...  exng  oldpeak  slp  caa  thall  output
# 0   63    1   3     145   233    1  ...     0      2.3    0    0      1       1
# 1   37    1   2     130   250    0  ...     0      3.5    0    0      2       1
# 2   41    0   1     130   204    0  ...     0      1.4    2    0      2       1
# 3   56    1   1     120   236    0  ...     0      0.8    2    0      2       1
# 4   57    0   0     120   354    0  ...     1      0.6    2    0      2       1
#
# [5 rows x 14 columns]

# %%
test_data.head()
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5

# %%
train_data.shape
# Out:
# (303, 14)

# %%
test_data.shape
# Out:
# (3585, 1)

# %%
train_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   98.6    3585 non-null   float64
# dtypes: float64(1)
# memory usage: 28.1 KB

# %%
train_data.describe()
# Out:
#               age         sex          cp  ...         caa       thall      output
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
train_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# 98.6    0
# dtype: int64

# %%
train_data.duplicated().sum()
# Out:
# 1

# %%
train_data.drop_duplicates(inplace=True)

# %%
plt.figure(figsize = (15,6))
sns.countplot(x="age",data=train_data)
plt.title('Age of Patients')
# Out:
# Text(0.5, 1.0, 'Age of Patients')

# %%
sns.countplot(x = 'sex' , hue = 'output' ,  data = train_data)
plt.title("Distribution of Gender w.r.t. Heart Attack" , fontsize= 15)
plt.show()

# %%
sns.barplot(x="cp",y ='output' ,data=train_data);
plt.title("Distribution of Chest Pain w.r.t. Heart Attack" , fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Distribution of Chest Pain w.r.t. Heart Attack')

# %%
sns.barplot(x="fbs",y ='output' ,data=train_data);
plt.title("Distribution of fasting Blood Sugar w.r.t. Heart Attack" , fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Distribution of fasting Blood Sugar w.r.t. Heart Attack')

# %%
sns.countplot(x = 'restecg' , hue = 'output' ,  data = train_data)
plt.title("Distribution of Resting Electrocardiographic results w.r.t. Heart Attack" , fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Distribution of Resting Electrocardiographic results w.r.t. Heart Attack')

# %%
sns.countplot(x = 'caa' , hue = 'output' ,  data = train_data)
plt.title("Distribution of no. of major blood vessels w.r.t. Heart Attack" , fontsize= 15)
# Out:
# Text(0.5, 1.0, 'Distribution of no. of major blood vessels w.r.t. Heart Attack')

# %%
sns.violinplot(x='cp',y='trtbps',data=train_data)

# %%
plt.hist(x="thalachh",data=train_data)
# Out:
# (array([ 1.,  6., 11., 26., 35., 53., 77., 62., 26.,  5.]),
#  array([ 71. ,  84.1,  97.2, 110.3, 123.4, 136.5, 149.6, 162.7, 175.8,
#         188.9, 202. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x="oldpeak",data=train_data)
# Out:
# (array([148.,  50.,  40.,  24.,  20.,  11.,   6.,   1.,   0.,   2.]),
#  array([0.  , 0.62, 1.24, 1.86, 2.48, 3.1 , 3.72, 4.34, 4.96, 5.58, 6.2 ]),
#  <a list of 10 Patch objects>)

# %%
sns.lineplot(y='trtbps',x='age',data=train_data)
plt.title('blood pressure with age')
plt.xlabel('age')
plt.ylabel('blood pressure')
plt.show()

# %%
sns.lineplot(y='chol',x='age',data=train_data)
plt.title('cholestrol level with age')
plt.xlabel('age')
plt.ylabel('cholestrol level')
plt.show()

# %%
sns.lineplot(y='thalachh',x='age',data=train_data)
plt.title('heart rate with age')
plt.xlabel('age')
plt.ylabel('heart rate')
plt.show()

# %%
sns.lineplot(x='age',y='thalachh',hue='output',data=train_data)
plt.title('effect of heart attack with increase in age and heart rate')
plt.show()

# %%
sns.lineplot(x='age',y='chol',hue='output',data=train_data)
plt.title('effect of heart attack with increase in age and cholestrol')
plt.show()

# %%
plt.scatter(train_data['restecg'], train_data['oldpeak'])

# %%
sex_hrt = train_data.groupby('sex')[['output']].mean()

plt.pie(sex_hrt.output, labels = sex_hrt.index.map({0: 'Female', 1: 'Male'}), textprops = {'fontsize': 15}, autopct = '%1.2f%%')
       
plt.title('Chance of getting (if compared according to genders)', fontsize = 20)
plt.show()

# %%
train_data.hist(figsize=(20,10))
plt.show()

# %%
train_data.corr()
# Out:
#                age       sex        cp  ...       caa     thall    output
# age       1.000000 -0.094962 -0.063107  ...  0.302261  0.065317 -0.221476
# sex      -0.094962  1.000000 -0.051740  ...  0.113060  0.211452 -0.283609
# cp       -0.063107 -0.051740  1.000000  ... -0.195356 -0.160370  0.432080
# trtbps    0.283121 -0.057647  0.046486  ...  0.099248  0.062870 -0.146269
# chol      0.207216 -0.195571 -0.072682  ...  0.086878  0.096810 -0.081437
# fbs       0.119492  0.046022  0.096018  ...  0.144935 -0.032752 -0.026826
# restecg  -0.111590 -0.060351  0.041561  ... -0.083112 -0.010473  0.134874
# thalachh -0.395235 -0.046439  0.293367  ... -0.228311 -0.094910  0.419955
# exng      0.093216  0.143460 -0.392937  ...  0.125377  0.205826 -0.435601
# oldpeak   0.206040  0.098322 -0.146692  ...  0.236560  0.209090 -0.429146
# slp      -0.164124 -0.032990  0.116854  ... -0.092236 -0.103314  0.343940
# caa       0.302261  0.113060 -0.195356  ...  1.000000  0.160085 -0.408992
# ...

# %%
plt.figure(figsize=(30,15))
a = sns.heatmap(train_data.corr(), annot=True, fmt='.1f')
sns.heatmap(train_data.corr())

# %%
X_train = train_data.drop(['output'],axis =1).values
Y_train = train_data['output'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X_train, Y_train, test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(x_test , y_test)
# Out:
# 0.4813416215830192

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 0.83662782,  0.25715886, -0.1478844 ,  0.3202197 ,  0.4804303 ,
#         0.90493583,  0.92393453,  0.35275493,  0.55950997,  0.6173538 ,
#         0.36517061, -0.16606508, -0.08655091,  0.52529522,  1.04710524,
#        -0.0109218 ,  0.60581152,  0.5315549 ,  0.93269575, -0.1014831 ,
#         0.31600211,  0.84699784,  0.02494742,  0.59196104,  0.71532937,
#         0.89410825, -0.16827223,  0.76080572,  0.25312131,  0.9549611 ,
#         1.16570671,  0.57143685,  0.3629713 ,  0.33402062,  0.79033398,
#        -0.02906953,  0.68753675,  0.29958916,  0.85318336,  0.88067842,
#        -0.27008903,  0.15055727,  0.16339645,  0.49403055,  0.26749225,
#         0.93282978,  0.55259599,  0.69084969,  0.60811729,  0.09544043,
#         0.82258429,  0.42865572,  0.55546072,  1.1695945 ,  0.9755517 ,
#         0.73234473,  1.33730507,  0.28688579,  0.39974376,  0.98701175,
#         1.05272421])

# %%
model.intercept_
# Out:
# 0.9910645641530096

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train , y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8524590163934426
